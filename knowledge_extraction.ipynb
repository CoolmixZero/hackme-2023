# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
evt = pd.read_csv('data/dc_evt_modified2.csv')
timeline = pd.read_csv('data/dc01-super-timeline.csv')
sus_files = pd.read_csv('./one_class_svm_inodes.csv').iloc[:, 1:]
# Out:
# /tmp/ipykernel_42815/1341618093.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   evt = pd.read_csv('data/dc_evt_modified2.csv')
# /tmp/ipykernel_42815/1341618093.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   timeline = pd.read_csv('data/dc01-super-timeline.csv')

# %%
pd.merge(sus_files, timeline, on=['inode', 'filename'], how='inner')
# Out:
#         inode                                           filename        date  \
# 0           0                                         NTFS:\$MFT  06/18/2013
# 1           0                                         NTFS:\$MFT  06/18/2013
# 2           0                                         NTFS:\$MFT  06/18/2013
# 3           0                                         NTFS:\$MFT  06/18/2013
# 4           0                                         NTFS:\$MFT  06/18/2013
# ...       ...                                                ...         ...
# 515999  87112  NTFS:\Users\Administrator\AppData\Roaming\Micr...  09/18/2020
# 516000  87112  NTFS:\Users\Administrator\AppData\Roaming\Micr...  09/19/2020
# 516001  87112  NTFS:\Users\Administrator\AppData\Roaming\Micr...  09/19/2020
# 516002  87112  NTFS:\Users\Administrator\AppData\Roaming\Micr...  09/19/2020
# 516003  87112  NTFS:\Users\Administrator\AppData\Roaming\Micr...  09/19/2020
#
#             time timezone  MACB source             sourcetype  \
# 0       18:32:10      UTC  M...   FILE         NTFS file stat
# 1       18:32:14      UTC  M...   FILE         NTFS file stat
# 2       18:32:14      UTC  M...   FILE         NTFS file stat
# 3       18:32:15      UTC  M...   FILE         NTFS file stat
# 4       18:32:15      UTC  M...   FILE         NTFS file stat
# ...          ...      ...   ...    ...                    ...
# 515999  22:39:22      UTC  MA..   FILE  File entry shell item
# 516000  01:22:37      UTC  ...B    LOG                 System
# 516001  03:34:56      UTC  MA.B    LNK       Windows Shortcut
# 516002  03:34:58      UTC  MA.B   FILE  File entry shell item
# 516003  03:35:07      UTC  MACB   FILE              File stat
#
#                                                      type user host  \
# 0                               Content Modification Time    -    -
# 1                               Content Modification Time    -    -
# 2                               Content Modification Time    -    -
# 3                               Content Modification Time    -    -
# 4                               Content Modification Time    -    -
# ...                                                   ...  ...  ...
# 515999        Content Modification Time; Last Access Time    -    -
# 516000                                      Creation Time    -    -
# 516001  Content Modification Time; Creation Time; Last...    -    -
# 516002  Content Modification Time; Creation Time; Last...    -    -
# 516003  Content Modification Time; Creation Time; Last...    -    -
#
#                                                     short  \
# 0                     \$MFT 43919-1 $STANDARD_INFORMATION
# 1                     \$MFT 37226-1 $STANDARD_INFORMATION
# 2                     \$MFT 37234-1 $STANDARD_INFORMATION
# 3                     \$MFT 37237-1 $STANDARD_INFORMATION
# 4                     \$MFT 37075-1 $STANDARD_INFORMATION
# ...                                                   ...
# 515999  Name: Secret NTFS file reference: 86966-9 Orig...
# 516000  9a4ddb3f-fa16-11ea-80bf-000c29e184e6 Origin: B...
# 516001                C:\FileShare\Secret\Beth_Secret.txt
# 516002  Name: Beth_Secret.txt NTFS file reference: 871...
# 516003  \Users\Administrator\AppData\Roaming\Microsoft...
#
#                                                      desc  version notes  \
# 0       NTFS:\$MFT File reference: 43919-1 Attribute n...        2     -
# 1       NTFS:\$MFT File reference: 37226-1 Attribute n...        2     -
# 2       NTFS:\$MFT File reference: 37234-1 Attribute n...        2     -
# 3       NTFS:\$MFT File reference: 37237-1 Attribute n...        2     -
# 4       NTFS:\$MFT File reference: 37075-1 Attribute n...        2     -
# ...                                                   ...      ...   ...
# 515999  Name: Secret Long name: Secret NTFS file refer...        2     -
# 516000  9a4ddb3f-fa16-11ea-80bf-000c29e184e6 MAC addre...        2     -
# 516001  File size: 0 File attribute flags: 0x00000020 ...        2     -
# 516002  Name: BETH_S~1.TXT Long name: Beth_Secret.txt ...        2     -
# 516003  NTFS:\Users\Administrator\AppData\Roaming\Micr...        2     -
#
#                  format                                              extra
# 0                   mft  attribute_type: 16; file_system_type: NTFS; is...
# 1                   mft  attribute_type: 16; file_system_type: NTFS; is...
# 2                   mft  attribute_type: 16; file_system_type: NTFS; is...
# 3                   mft  attribute_type: 16; file_system_type: NTFS; is...
# 4                   mft  attribute_type: 16; file_system_type: NTFS; is...
# ...                 ...                                                ...
# 515999  lnk/shell_items  sha256_hash: 74b59e132c52c863b832ead37d745d22b...
# 516000              lnk  sha256_hash: 74b59e132c52c863b832ead37d745d22b...
# 516001              lnk  birth_droid_file_identifier: 9a4ddb3f-fa16-11e...
# 516002  lnk/shell_items  sha256_hash: 74b59e132c52c863b832ead37d745d22b...
# 516003         filestat  file_size: 825; file_system_type: NTFS; is_all...
#
# [516004 rows x 17 columns]
