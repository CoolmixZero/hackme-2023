# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
evt = pd.read_csv('data/dc_evt_modified2.csv')
timeline = pd.read_csv('data/dc01-super-timeline.csv')
sus_files = pd.read_csv('./one_class_svm_inodes.csv').iloc[:, 1:]
# Out:
# /tmp/ipykernel_42815/1341618093.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   evt = pd.read_csv('data/dc_evt_modified2.csv')
# /tmp/ipykernel_42815/1341618093.py:2: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   timeline = pd.read_csv('data/dc01-super-timeline.csv')

# %%
sus_files
# Out:
#     inode                                           filename
# 0       0                                         NTFS:\$MFT
# 1       1                                     NTFS:\$MFTMirr
# 2   19401                                      NTFS:\BOOTNXT
# 3   19411                                      NTFS:\bootmgr
# 4   19534  NTFS:\Windows\WinSxS\amd64_microsoft.windows.p...
# 5   19535  NTFS:\ProgramData\Microsoft\Windows\Start Menu...
# 6   19539  NTFS:\Windows\WinSxS\amd64_microsoft.windows.p...
# 7   19540  NTFS:\ProgramData\Microsoft\Windows\Start Menu...
# 8   19586  NTFS:\Users\Default\AppData\Local\Microsoft\Wi...
# 9   19628  NTFS:\Users\Default\AppData\Local\Microsoft\Wi...
# 10  19635  NTFS:\Users\Default\AppData\Roaming\Microsoft\...
# 11  19665             NTFS:\Users\Public\Desktop\desktop.ini
# 12  20377  NTFS:\Users\Administrator\AppData\Local\Micros...
# 13  20479  NTFS:\Users\Administrator\AppData\Roaming\Micr...
# ...
